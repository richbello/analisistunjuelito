# %% [markdown]
# <a href="https://colab.research.google.com/github/richbello/analisistunjuelito/blob/main/Medioambiente_aire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el DataFrame
data = {
    'A\u00f1o': [2021, 2022, 2023, 2024],
    'Velocidad Viento Min (m/s)': [0, 0, 0, 0.1],
    'Velocidad Viento M\u00e1x (m/s)': [4.9, 4.8, 5.0, 4.8],
    'Promedio Velocidad Viento (m/s)': [1.2, 1.1, 1.3, 1.4],
    'Desviaci\u00f3n Est\u00e1ndar Velocidad Viento': [0.8, 0.8, 0.8, 0.9],
    'Direcci\u00f3n Viento Min (\u00b0)': [0, 0, 0, 0],
    'Direcci\u00f3n Viento M\u00e1x (\u00b0)': [359, 360, 360, 360],
    'Temperatura Promedio (\u00b0C)': [15.3, 15.1, 15.7, 16.1]
}

df = pd.DataFrame(data)

# Configurar el estilo de seaborn
sns.set_style("whitegrid")

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar las l\u00edneas
sns.lineplot(data=df, x='A\u00f1o', y='Velocidad Viento Min (m/s)', marker='o', label='Vel. Viento Min')
sns.lineplot(data=df, x='A\u00f1o', y='Velocidad Viento M\u00e1x (m/s)', marker='o', label='Vel. Viento M\u00e1x')
sns.lineplot(data=df, x='A\u00f1o', y='Promedio Velocidad Viento (m/s)', marker='o', label='Promedio Vel. Viento')
sns.lineplot(data=df, x='A\u00f1o', y='Temperatura Promedio (\u00b0C)', marker='o', label='Temperatura Promedio')

# Configurar el t\u00edtulo y las etiquetas
plt.title('Datos de Viento y Temperatura (2021-2024)', fontsize=16)
plt.xlabel('A\u00f1o', fontsize=12)
plt.ylabel('Valores', fontsize=12)

# Ajustar la leyenda
plt.legend(fontsize=10, loc='center left', bbox_to_anchor=(1, 0.5))

# Ajustar los m\u00e1rgenes
plt.tight_layout()

# Guardar la figura como PNG
plt.savefig('datos_viento_temperatura.png', dpi=300, bbox_inches='tight')

print("El gr\u00e1fico ha sido guardado como 'datos_viento_temperatura.png'")

# Mostrar el gr\u00e1fico
plt.show()
# Out:
# El gráfico ha sido guardado como 'datos_viento_temperatura.png'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el DataFrame con los datos proporcionados
data = {
    'Año': [2021, 2022, 2023, 2024],
    'NO2 Min (ppb)': [0, 0, 0, 0.3],
    'NO2 Máx (ppb)': [294.9, 263.5, 331.8, 355.6],
    'Promedio NO2 (ppb)': [31.6, 32.1, 27.1, 35.8],
    'NOX Min (ppb)': [0, 0, 0, 0.3],
    'NOX Máx (ppb)': [88.4, 87.7, 94.6, 99.5],
    'Promedio NOX (ppb)': [63.2, 63.7, 61.9, 67.1],
    'Ozono Máx (ppb)': [171, 109, 141, 116],
    'Promedio Ozono (ppb)': [13.4, 19.8, 18.2, 20.5],
    'Humedad Relativa (%)': [70.6, 73.8, 69, 75.9]
}

df = pd.DataFrame(data)

# Configurar el estilo de seaborn
sns.set_style("whitegrid")

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar las líneas
sns.lineplot(data=df, x='Año', y='NO2 Máx (ppb)', marker='o', label='NO2 Máx')
sns.lineplot(data=df, x='Año', y='Promedio NO2 (ppb)', marker='o', label='Promedio NO2')
sns.lineplot(data=df, x='Año', y='NOX Máx (ppb)', marker='o', label='NOX Máx')
sns.lineplot(data=df, x='Año', y='Promedio NOX (ppb)', marker='o', label='Promedio NOX')
sns.lineplot(data=df, x='Año', y='Ozono Máx (ppb)', marker='o', label='Ozono Máx')
sns.lineplot(data=df, x='Año', y='Promedio Ozono (ppb)', marker='o', label='Promedio Ozono')
sns.lineplot(data=df, x='Año', y='Humedad Relativa (%)', marker='o', label='Humedad Relativa')

# Configurar el título y las etiquetas
plt.title('Datos de Calidad del Aire (2021-2024)', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Valores', fontsize=12)

# Ajustar la leyenda
plt.legend(fontsize=10, loc='center left', bbox_to_anchor=(1, 0.5))

# Ajustar los márgenes
plt.tight_layout()

# Guardar la figura como PNG
plt.savefig('datos_calidad_aire.png', dpi=300, bbox_inches='tight')

print("El gráfico ha sido guardado como 'datos_calidad_aire.png'")

# Mostrar el gráfico
plt.show()
# Out:
# El gráfico ha sido guardado como 'datos_calidad_aire.png'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el DataFrame con los datos proporcionados
data = {
    'Año': [2021, 2022, 2023, 2024],
    'Precipitación Máx (mm)': [244.3, 228, 257.9, 295.4],
    'Promedio Precipitación (mm)': [16.9, 18, 14.2, 20.1],
    'Radiación Solar Máx (W/m²)': [1179, 1141, 900, 1297],
    'Promedio Radiación Solar (W/m²)': [173, 153, 135, 165]
}

df = pd.DataFrame(data)

# Configurar el estilo de seaborn
sns.set_style("whitegrid")

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 8))

# Graficar las líneas
sns.lineplot(data=df, x='Año', y='Precipitación Máx (mm)', marker='o', label='Precipitación Máx')
sns.lineplot(data=df, x='Año', y='Promedio Precipitación (mm)', marker='o', label='Promedio Precipitación')
sns.lineplot(data=df, x='Año', y='Radiación Solar Máx (W/m²)', marker='o', label='Radiación Solar Máx')
sns.lineplot(data=df, x='Año', y='Promedio Radiación Solar (W/m²)', marker='o', label='Promedio Radiación Solar')

# Configurar el título y las etiquetas
plt.title('Datos de Precipitación y Radiación Solar (2021-2024)', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Valores', fontsize=12)

# Ajustar la leyenda
plt.legend(fontsize=10, loc='center left', bbox_to_anchor=(1, 0.5))

# Ajustar los márgenes
plt.tight_layout()

# Guardar la figura como PNG
plt.savefig('datos_precipitacion_radiacion.png', dpi=300, bbox_inches='tight')

print("El gráfico ha sido guardado como 'datos_precipitacion_radiacion.png'")

# Mostrar el gráfico
plt.show()
# Out:
# El gráfico ha sido guardado como 'datos_precipitacion_radiacion.png'
